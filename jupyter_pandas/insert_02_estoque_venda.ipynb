# %%
import random
from datetime import datetime, timedelta

# %%
import psycopg2

# cria conexão
def conn():
  con = psycopg2.connect(
    database = "drogasystem", 
    user = "oscar", 
    password = "oscar", 
    host = "127.0.0.1", 
    port = "5432")
  cur = con.cursor()
  return con, cur

# faz selects
def select(sql):
  all = []
  con, cur = conn()
  cur.execute(sql)
  all = cur.fetchall()
  cur.close()
  con.close()
  return all

# executa inserts e updates
def exec(sql):
  try:
    con, cur = conn()
    cur.execute(sql)
    con.commit()
  except (Exception, psycopg2.Error) as error:
    if cur == None: cur.rollback()
    print("Error:", error)
  finally:
    if cur: cur.close()
    if con: con.close()

# %%
# atualizar estoque
def estoque(dat, med_id, preco, fval, fpre):
  # lote
  lot = random.randrange(100000, 999999)

  # data da validade
  val = dat + timedelta(days = fval * 30 + 30)
  val = datetime.strptime(val.strftime('1/%m/%Y'), '%d/%m/%Y').date() - timedelta(days = 1)
  
  # preco de compra
  pre = float(preco)
  pre = int(pre / fpre * 10)
  pre /= 10

  # quantidade comprada
  if preco > 600:
    qtd = random.randrange(2, 7, 2)
  elif preco > 300:
    qtd = random.randrange(3, 10, 3)
  elif preco > 100:
    qtd = random.randrange(5, 16, 5)
  elif preco > 40:
    qtd = random.randrange(2, 20, 4)
  else:
    qtd = random.randrange(3, 49, 4)

  sql = "insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) "
  sql += f"values ({med_id}, 'lote {lot}', '{dat}', '{val}', {pre}, {qtd}, {qtd}); \n"

  # if model.find_by_sql(f"select count(*) from estoque_total where medicamento_id = {med_id}; ")[0][0] == 0:
  if select(f"select count(*) from estoque_total where medicamento_id = {med_id};")[0][0] == 0:
    if preco > 400:
      min = 3
    elif preco > 100:
      min = 5
    else:
      min = 10
    sql += f"insert into estoque_total (medicamento_id, total, minimo) values ({med_id}, {qtd}, {min}); "
  else:
    sql += f"update estoque_total set total = total + {qtd} where medicamento_id = {med_id}; "
    
  return sql

# %%
# venda
def venda(clis, pros, dat, venda_id):
  sql = ""
  sql1 = ""
  sql2 = ""
  sql3 = ""
  total = 0

  # cliente e profissional
  pro = None
  cli = None
  if random.randrange(3) > 0:
    cli = str(clis[random.randrange(len(clis))][0])

  # produtos em estoque
  s = "select estoque.id, estoque.medicamento_id, estoque.quant_atual, medicamento.preco, medicamento.controle, "
  s += "estoque.preco, estoque.data, estoque.validade, estoque_total.minimo from estoque "
  s += "inner join medicamento on medicamento.id = estoque.medicamento_id "
  s += "inner join estoque_total on estoque_total.medicamento_id = estoque.medicamento_id "
  s += "where quant_atual > 0 order by 1;"
  ests = select(s)

  # quantidade de itens da venda
  qiv = random.randrange(3) + 1
  for i in range(qiv):

    # escolha do produto
    p = random.randrange(len(ests))

    est_id = ests[p][0]
    med_id = ests[p][1]
    qtd_atu = ests[p][2]
    preco = float(ests[p][3])
    contr = ests[p][4]
    
    # VERIFICAR SE É MEDICAMENTO CONTROLADO!!!
    # profissional
    if contr != "Não controlado":
      pro = str(pros[random.randrange(len(pros))][0])

    # quantidade do produto
    if preco > 200:
      qtd_vnd = random.randrange(3) + 1
    elif preco > 50:
      qtd_vnd = random.randrange(5) + 1
    else:
      qtd_vnd = random.randrange(10) + 1
    if qtd_vnd > qtd_atu:
      qtd_vnd = qtd_atu

    # desconto para cliente de até 40% e 10% de chance dar desconto para não cliente até 10%
    desc = 0
    if cli:
      desc = qtd_vnd * preco * random.randrange(40) / 100
      desc = int(desc * 10) / 10
    elif random.randrange(10) > 0:
      desc = qtd_vnd * preco * random.randrange(10) / 100
      desc = int(desc * 10) / 10

    # totais
    tot = qtd_vnd * preco - desc
    total += tot

    sql1 += "insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) "
    sql1 += f"values ({venda_id}, {med_id}, {est_id}, {qtd_vnd}, {desc:.2f}, {tot:.2f}); \n"
    sql1 += f"update estoque set quant_venda = quant_venda + {qtd_vnd}, quant_atual = quant_atual - {qtd_vnd} where id = {est_id}; \n"
    sql1 += f"update estoque_total set total = total - {qtd_vnd} where medicamento_id = {med_id}; \n"

    # reposição do estoque
    if qtd_atu < ests[p][8]:
      pr = ests[p][3]
      fval = (ests[p][7] - ests[p][6]).days / 30
      fpre = float(ests[p][3] / ests[p][5])
      sql2 += estoque(dat.date(), med_id, pr, fval, fpre) + "\n"
  
  sql3 = f"insert into venda ({'cliente_id, ' if cli else ''}{'profissional_id, ' if pro else ''}time_stamp, total) "
  sql3 += f"values ({cli + ', ' if cli else ''}{pro + ', ' if pro else ''}'{dat}', {total:.2f}); \n"
  sql = sql3 + sql1 + sql2
  print(sql)
  exec(sql)

# %%
if select(f"select count(*) from estoque;")[0][0] == 0:
  print("\n-- estoque inicial")
  meds = select(f"select id, nome, preco from medicamento order by 1;")
  
  dic = {}
  for med in meds:
    if (not med[1] in dic):
      dic[med[1]] = {}
      dic[med[1]]["val"] = random.randrange(6, 37, 6) # fator de validade
      dic[med[1]]["pre"] = random.uniform(1.8, 2.9) # fator de preço
      
  for med in meds:
    # data da compra
    dat = datetime.strptime('31/07/23', '%d/%m/%y').date()
    sql = estoque(dat, med[0], med[2], dic[med[1]]["val"], dic[med[1]]["pre"])
    print(sql)
    exec(sql)

# %%
# Vendas
print("\n-- vendas, itens de venda")

# possiveis clientes e profissionais
clis = select("select id from cliente;")
pros = select("select id from profissional;")

# data inicial
if select("select count(*) from venda;")[0][0] == 0:
  dat = datetime.strptime('01/08/23', '%d/%m/%y')
else:
  dat = select("select max(time_stamp) from venda;")[0][0]
  dat = datetime.strptime(dat.strftime('%d/%m/%y'), '%d/%m/%y')

# venda_id inicial
venda_id = select("select coalesce(max(id), 0) as id from venda;")[0][0]

# período de venda
for i in range(90):
  dat += timedelta(days = 1)
  dat += timedelta(seconds = random.randrange(36000))

  # quantidade de vendas no dia
  qtd_vnd_dia = random.randrange(5)
  for j in range(qtd_vnd_dia):
    venda_id += 1
    dat += timedelta(seconds = random.randrange(14000))
    venda(clis, pros, dat, venda_id)
# Out:
# -- vendas, itens de venda
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (4, 21, '2023-08-02 09:25:20', 361.12);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (1, 256, 256, 5, 131.80, 267.65);
# update estoque set quant_venda = quant_venda + 5, quant_atual = quant_atual - 5 where id = 256;
# update estoque_total set total = total - 5 where medicamento_id = 256;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (1, 426, 426, 3, 32.60, 76.18);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 426;
# update estoque_total set total = total - 3 where medicamento_id = 426;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (1, 151, 151, 1, 1.70, 17.29);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 151;
# update estoque_total set total = total - 1 where medicamento_id = 151;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (5, 24, '2023-08-02 10:18:16', 221.05);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (2, 237, 237, 1, 51.30, 83.93);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 237;
# update estoque_total set total = total - 1 where medicamento_id = 237;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (2, 324, 324, 3, 21.00, 37.56);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 324;
# update estoque_total set total = total - 3 where medicamento_id = 324;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (2, 208, 208, 2, 7.40, 99.56);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 208;
# update estoque_total set total = total - 2 where medicamento_id = 208;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (208, 'lote 891281', '2023-08-02', '2024-08-31', 22.1, 2, 2);
# update estoque_total set total = total + 2 where medicamento_id = 208;
#
# insert into venda (profissional_id, time_stamp, total) values (24, '2023-08-02 13:47:55', 23.40);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (3, 443, 443, 1, 0.00, 23.40);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 443;
# update estoque_total set total = total - 1 where medicamento_id = 443;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (6, 24, '2023-08-03 16:20:33', 607.55);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (4, 78, 78, 1, 13.10, 174.47);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 78;
# update estoque_total set total = total - 1 where medicamento_id = 78;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (4, 332, 332, 3, 54.80, 134.32);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 332;
# update estoque_total set total = total - 3 where medicamento_id = 332;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (4, 39, 39, 2, 183.00, 298.76);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 39;
# update estoque_total set total = total - 2 where medicamento_id = 39;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (332, 'lote 625730', '2023-08-03', '2024-02-29', 26.9, 2, 2);
# update estoque_total set total = total + 2 where medicamento_id = 332;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (2, 24, '2023-08-03 16:29:03', 734.89);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (5, 68, 68, 5, 44.60, 699.10);
# update estoque set quant_venda = quant_venda + 5, quant_atual = quant_atual - 5 where id = 68;
# update estoque_total set total = total - 5 where medicamento_id = 68;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (5, 318, 318, 1, 20.10, 35.79);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 318;
# update estoque_total set total = total - 1 where medicamento_id = 318;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (13, 21, '2023-08-07 05:48:35', 446.78);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (6, 103, 103, 4, 28.50, 446.78);
# update estoque set quant_venda = quant_venda + 4, quant_atual = quant_atual - 4 where id = 103;
# update estoque_total set total = total - 4 where medicamento_id = 103;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (2, 22, '2023-08-07 08:13:29', 258.52);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (7, 12, 12, 2, 64.60, 258.52);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 12;
# update estoque_total set total = total - 2 where medicamento_id = 12;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (4, 23, '2023-08-07 10:32:09', 757.50);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (8, 134, 134, 4, 162.00, 378.00);
# update estoque set quant_venda = quant_venda + 4, quant_atual = quant_atual - 4 where id = 134;
# update estoque_total set total = total - 4 where medicamento_id = 134;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (8, 82, 82, 2, 186.80, 379.50);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 82;
# update estoque_total set total = total - 2 where medicamento_id = 82;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (17, 22, '2023-08-07 11:27:49', 27.14);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (9, 480, 480, 1, 4.40, 27.14);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 480;
# update estoque_total set total = total - 1 where medicamento_id = 480;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (17, 21, '2023-08-08 22:27:03', 155.01);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (10, 33, 33, 1, 79.80, 155.01);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 33;
# update estoque_total set total = total - 1 where medicamento_id = 33;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (14, 22, '2023-08-09 01:45:49', 52.10);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (11, 309, 309, 4, 3.90, 52.10);
# update estoque set quant_venda = quant_venda + 4, quant_atual = quant_atual - 4 where id = 309;
# update estoque_total set total = total - 4 where medicamento_id = 309;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (20, 24, '2023-08-10 15:05:57', 689.75);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (12, 203, 203, 3, 151.30, 689.75);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 203;
# update estoque_total set total = total - 3 where medicamento_id = 203;
#
# insert into venda (profissional_id, time_stamp, total) values (22, '2023-08-10 17:02:14', 951.84);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (13, 366, 366, 2, 1.90, 97.16);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 366;
# update estoque_total set total = total - 2 where medicamento_id = 366;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (13, 22, 22, 1, 0.00, 299.98);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 22;
# update estoque_total set total = total - 1 where medicamento_id = 22;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (13, 5, 5, 2, 0.00, 554.70);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 5;
# update estoque_total set total = total - 2 where medicamento_id = 5;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (366, 'lote 474748', '2023-08-10', '2025-08-31', 18.9, 10, 10);
# update estoque_total set total = total + 10 where medicamento_id = 366;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (16, 22, '2023-08-10 19:41:58', 715.40);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (14, 147, 147, 5, 97.50, 715.40);
# update estoque set quant_venda = quant_venda + 5, quant_atual = quant_atual - 5 where id = 147;
# update estoque_total set total = total - 5 where medicamento_id = 147;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (4, 22, '2023-08-10 22:13:48', 393.30);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (15, 470, 470, 5, 43.70, 393.30);
# update estoque set quant_venda = quant_venda + 5, quant_atual = quant_atual - 5 where id = 470;
# update estoque_total set total = total - 5 where medicamento_id = 470;
#
# insert into venda (profissional_id, time_stamp, total) values (24, '2023-08-13 01:22:52', 423.96);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (16, 414, 414, 5, 0.00, 192.50);
# update estoque set quant_venda = quant_venda + 5, quant_atual = quant_atual - 5 where id = 414;
# update estoque_total set total = total - 5 where medicamento_id = 414;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (16, 454, 454, 1, 7.10, 81.88);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 454;
# update estoque_total set total = total - 1 where medicamento_id = 454;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (16, 294, 294, 9, 0.00, 149.58);
# update estoque set quant_venda = quant_venda + 9, quant_atual = quant_atual - 9 where id = 294;
# update estoque_total set total = total - 9 where medicamento_id = 294;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (11, 23, '2023-08-13 04:22:25', 545.75);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (17, 321, 321, 9, 5.00, 247.45);
# update estoque set quant_venda = quant_venda + 9, quant_atual = quant_atual - 9 where id = 321;
# update estoque_total set total = total - 9 where medicamento_id = 321;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (17, 294, 294, 4, 7.30, 59.18);
# update estoque set quant_venda = quant_venda + 4, quant_atual = quant_atual - 4 where id = 294;
# update estoque_total set total = total - 4 where medicamento_id = 294;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (17, 236, 236, 2, 26.50, 239.12);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 236;
# update estoque_total set total = total - 2 where medicamento_id = 236;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (8, 24, '2023-08-13 07:52:29', 1217.27);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (18, 101, 101, 3, 198.70, 795.05);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 101;
# update estoque_total set total = total - 3 where medicamento_id = 101;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (18, 462, 462, 4, 9.00, 66.72);
# update estoque set quant_venda = quant_venda + 4, quant_atual = quant_atual - 4 where id = 462;
# update estoque_total set total = total - 4 where medicamento_id = 462;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (18, 316, 316, 3, 183.00, 355.50);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 316;
# update estoque_total set total = total - 3 where medicamento_id = 316;
#
# insert into venda (profissional_id, time_stamp, total) values (22, '2023-08-13 10:46:10', 1201.46);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (19, 99, 99, 3, 54.80, 858.82);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 99;
# update estoque_total set total = total - 3 where medicamento_id = 99;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (19, 160, 160, 1, 17.80, 279.40);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 160;
# update estoque_total set total = total - 1 where medicamento_id = 160;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (19, 247, 247, 1, 6.20, 63.24);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 247;
# update estoque_total set total = total - 1 where medicamento_id = 247;
#
# insert into venda (profissional_id, time_stamp, total) values (25, '2023-08-14 15:49:27', 482.68);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (20, 96, 96, 2, 25.40, 482.68);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 96;
# update estoque_total set total = total - 2 where medicamento_id = 96;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (10, 25, '2023-08-14 16:22:42', 385.94);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (21, 108, 108, 3, 246.70, 385.94);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 108;
# update estoque_total set total = total - 3 where medicamento_id = 108;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (1, 21, '2023-08-14 18:06:28', 647.49);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (22, 51, 51, 1, 27.10, 44.43);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 51;
# update estoque_total set total = total - 1 where medicamento_id = 51;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (22, 44, 44, 3, 78.40, 313.76);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 44;
# update estoque_total set total = total - 3 where medicamento_id = 44;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (22, 18, 18, 5, 67.80, 289.30);
# update estoque set quant_venda = quant_venda + 5, quant_atual = quant_atual - 5 where id = 18;
# update estoque_total set total = total - 5 where medicamento_id = 18;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (18, 'lote 981309', '2023-08-14', '2025-08-31', 33.1, 18, 18);
# update estoque_total set total = total + 18 where medicamento_id = 18;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (16, 21, '2023-08-14 21:46:38', 179.44);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (23, 349, 349, 6, 7.40, 179.44);
# update estoque set quant_venda = quant_venda + 6, quant_atual = quant_atual - 6 where id = 349;
# update estoque_total set total = total - 6 where medicamento_id = 349;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (5, 24, '2023-08-16 05:34:27', 678.84);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (24, 404, 404, 2, 0.90, 31.50);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 404;
# update estoque_total set total = total - 2 where medicamento_id = 404;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (24, 245, 245, 2, 59.10, 236.40);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 245;
# update estoque_total set total = total - 2 where medicamento_id = 245;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (24, 122, 122, 4, 151.90, 410.94);
# update estoque set quant_venda = quant_venda + 4, quant_atual = quant_atual - 4 where id = 122;
# update estoque_total set total = total - 4 where medicamento_id = 122;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (404, 'lote 814686', '2023-08-16', '2024-08-31', 8.0, 23, 23);
# update estoque_total set total = total + 23 where medicamento_id = 404;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (15, 25, '2023-08-16 05:52:36', 465.09);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (25, 91, 91, 3, 297.30, 465.09);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 91;
# update estoque_total set total = total - 3 where medicamento_id = 91;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (11, 23, '2023-08-16 06:47:39', 120.72);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (26, 504, 504, 1, 0.60, 6.15);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 504;
# update estoque_total set total = total - 1 where medicamento_id = 504;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (26, 145, 145, 1, 12.70, 114.57);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 145;
# update estoque_total set total = total - 1 where medicamento_id = 145;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (11, 21, '2023-08-18 19:07:09', 494.19);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (27, 146, 146, 4, 188.50, 461.82);
# update estoque set quant_venda = quant_venda + 4, quant_atual = quant_atual - 4 where id = 146;
# update estoque_total set total = total - 4 where medicamento_id = 146;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (27, 138, 138, 1, 11.90, 32.37);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 138;
# update estoque_total set total = total - 1 where medicamento_id = 138;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (16, 25, '2023-08-21 07:45:21', 382.36);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (28, 105, 105, 2, 72.80, 382.36);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 105;
# update estoque_total set total = total - 2 where medicamento_id = 105;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (4, 22, '2023-08-22 11:07:23', 254.00);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (29, 206, 206, 9, 88.00, 215.75);
# update estoque set quant_venda = quant_venda + 9, quant_atual = quant_atual - 9 where id = 206;
# update estoque_total set total = total - 9 where medicamento_id = 206;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (29, 242, 242, 9, 17.10, 38.25);
# update estoque set quant_venda = quant_venda + 9, quant_atual = quant_atual - 9 where id = 242;
# update estoque_total set total = total - 9 where medicamento_id = 242;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (12, 25, '2023-08-22 12:19:36', 1039.47);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (30, 92, 92, 6, 0.00, 289.44);
# update estoque set quant_venda = quant_venda + 6, quant_atual = quant_atual - 6 where id = 92;
# update estoque_total set total = total - 6 where medicamento_id = 92;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (30, 487, 487, 5, 310.20, 629.95);
# update estoque set quant_venda = quant_venda + 5, quant_atual = quant_atual - 5 where id = 487;
# update estoque_total set total = total - 5 where medicamento_id = 487;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (30, 289, 289, 2, 22.80, 120.08);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 289;
# update estoque_total set total = total - 2 where medicamento_id = 289;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (12, 21, '2023-08-22 15:12:56', 288.94);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (31, 78, 78, 2, 86.20, 288.94);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 78;
# update estoque_total set total = total - 2 where medicamento_id = 78;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (78, 'lote 518357', '2023-08-22', '2025-08-31', 89.9, 10, 10);
# update estoque_total set total = total + 10 where medicamento_id = 78;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (2, 25, '2023-08-22 16:31:40', 254.51);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (32, 179, 179, 7, 89.40, 254.51);
# update estoque set quant_venda = quant_venda + 7, quant_atual = quant_atual - 7 where id = 179;
# update estoque_total set total = total - 7 where medicamento_id = 179;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (19, 21, '2023-08-24 01:02:17', 243.19);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (33, 227, 227, 10, 3.50, 23.50);
# update estoque set quant_venda = quant_venda + 10, quant_atual = quant_atual - 10 where id = 227;
# update estoque_total set total = total - 10 where medicamento_id = 227;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (33, 346, 346, 1, 3.10, 41.83);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 346;
# update estoque_total set total = total - 1 where medicamento_id = 346;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (33, 438, 438, 4, 31.30, 177.86);
# update estoque set quant_venda = quant_venda + 4, quant_atual = quant_atual - 4 where id = 438;
# update estoque_total set total = total - 4 where medicamento_id = 438;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (19, 22, '2023-08-24 02:54:13', 583.82);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (34, 73, 73, 2, 21.10, 79.56);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 73;
# update estoque_total set total = total - 2 where medicamento_id = 73;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (34, 119, 119, 1, 52.60, 102.37);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 119;
# update estoque_total set total = total - 1 where medicamento_id = 119;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (34, 48, 48, 3, 172.10, 401.89);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 48;
# update estoque_total set total = total - 3 where medicamento_id = 48;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (73, 'lote 698317', '2023-08-24', '2026-02-28', 23.6, 14, 14);
# update estoque_total set total = total + 14 where medicamento_id = 73;
#
# insert into venda (profissional_id, time_stamp, total) values (24, '2023-08-24 03:56:19', 325.91);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (35, 366, 508, 7, 20.80, 325.91);
# update estoque set quant_venda = quant_venda + 7, quant_atual = quant_atual - 7 where id = 508;
# update estoque_total set total = total - 7 where medicamento_id = 366;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (13, 23, '2023-08-24 05:50:23', 1107.59);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (36, 396, 396, 3, 276.40, 747.50);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 396;
# update estoque_total set total = total - 3 where medicamento_id = 396;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (36, 243, 243, 3, 12.60, 102.84);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 243;
# update estoque_total set total = total - 3 where medicamento_id = 243;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (36, 131, 131, 3, 45.30, 257.25);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 131;
# update estoque_total set total = total - 3 where medicamento_id = 131;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (396, 'lote 283071', '2023-08-24', '2024-02-29', 142.8, 3, 3);
# update estoque_total set total = total + 3 where medicamento_id = 396;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (17, 24, '2023-08-26 19:54:59', 877.79);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (37, 9, 9, 3, 27.10, 877.79);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 9;
# update estoque_total set total = total - 3 where medicamento_id = 9;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (14, 25, '2023-08-28 01:09:59', 479.70);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (38, 229, 229, 3, 41.70, 479.70);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 229;
# update estoque_total set total = total - 3 where medicamento_id = 229;
#
# insert into venda (profissional_id, time_stamp, total) values (22, '2023-08-28 04:57:13', 1387.74);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (39, 172, 172, 3, 0.00, 409.02);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 172;
# update estoque_total set total = total - 3 where medicamento_id = 172;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (39, 195, 195, 2, 36.10, 480.80);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 195;
# update estoque_total set total = total - 2 where medicamento_id = 195;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (39, 197, 197, 2, 49.20, 497.92);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 197;
# update estoque_total set total = total - 2 where medicamento_id = 197;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (2, 25, '2023-08-29 05:12:09', 261.68);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (40, 365, 365, 6, 14.80, 84.32);
# update estoque set quant_venda = quant_venda + 6, quant_atual = quant_atual - 6 where id = 365;
# update estoque_total set total = total - 6 where medicamento_id = 365;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (40, 305, 305, 6, 83.40, 177.36);
# update estoque set quant_venda = quant_venda + 6, quant_atual = quant_atual - 6 where id = 305;
# update estoque_total set total = total - 6 where medicamento_id = 305;
#
# insert into venda (profissional_id, time_stamp, total) values (23, '2023-08-29 05:12:56', 242.28);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (41, 265, 265, 1, 2.00, 67.40);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 265;
# update estoque_total set total = total - 1 where medicamento_id = 265;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (41, 126, 126, 2, 13.10, 174.88);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 126;
# update estoque_total set total = total - 2 where medicamento_id = 126;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (126, 'lote 311489', '2023-08-29', '2025-02-28', 33.9, 10, 10);
# update estoque_total set total = total + 10 where medicamento_id = 126;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (10, 25, '2023-08-29 08:39:14', 636.57);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (42, 244, 244, 8, 36.10, 205.02);
# update estoque set quant_venda = quant_venda + 8, quant_atual = quant_atual - 8 where id = 244;
# update estoque_total set total = total - 8 where medicamento_id = 244;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (42, 124, 124, 5, 32.40, 431.55);
# update estoque set quant_venda = quant_venda + 5, quant_atual = quant_atual - 5 where id = 124;
# update estoque_total set total = total - 5 where medicamento_id = 124;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (124, 'lote 235014', '2023-08-29', '2026-02-28', 38.9, 6, 6);
# update estoque_total set total = total + 6 where medicamento_id = 124;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (5, 25, '2023-08-29 09:01:34', 273.88);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (43, 260, 260, 4, 30.40, 273.88);
# update estoque set quant_venda = quant_venda + 4, quant_atual = quant_atual - 4 where id = 260;
# update estoque_total set total = total - 4 where medicamento_id = 260;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (260, 'lote 203185', '2023-08-29', '2025-08-31', 39.9, 10, 10);
# update estoque_total set total = total + 10 where medicamento_id = 260;
#
# insert into venda (profissional_id, time_stamp, total) values (24, '2023-08-30 15:23:54', 1066.66);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (44, 29, 29, 1, 12.30, 296.84);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 29;
# update estoque_total set total = total - 1 where medicamento_id = 29;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (44, 22, 22, 1, 17.90, 282.08);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 22;
# update estoque_total set total = total - 1 where medicamento_id = 22;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (44, 147, 147, 3, 0.00, 487.74);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 147;
# update estoque_total set total = total - 3 where medicamento_id = 147;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (22, 'lote 827661', '2023-08-30', '2025-03-31', 131.7, 10, 10);
# update estoque_total set total = total + 10 where medicamento_id = 22;
#
# insert into venda (profissional_id, time_stamp, total) values (23, '2023-08-30 17:26:03', 107.88);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (45, 181, 181, 3, 0.00, 107.88);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 181;
# update estoque_total set total = total - 3 where medicamento_id = 181;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (181, 'lote 765135', '2023-08-30', '2026-03-31', 19.5, 31, 31);
# update estoque_total set total = total + 31 where medicamento_id = 181;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (6, 25, '2023-08-30 17:59:08', 306.39);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (46, 242, 242, 9, 2.20, 53.15);
# update estoque set quant_venda = quant_venda + 9, quant_atual = quant_atual - 9 where id = 242;
# update estoque_total set total = total - 9 where medicamento_id = 242;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (46, 315, 315, 4, 5.40, 130.12);
# update estoque set quant_venda = quant_venda + 4, quant_atual = quant_atual - 4 where id = 315;
# update estoque_total set total = total - 4 where medicamento_id = 315;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (46, 471, 471, 8, 20.00, 123.12);
# update estoque set quant_venda = quant_venda + 8, quant_atual = quant_atual - 8 where id = 471;
# update estoque_total set total = total - 8 where medicamento_id = 471;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (6, 24, '2023-08-31 20:01:17', 1426.01);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (47, 307, 307, 3, 94.30, 631.19);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 307;
# update estoque_total set total = total - 3 where medicamento_id = 307;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (47, 411, 411, 2, 4.30, 140.04);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 411;
# update estoque_total set total = total - 2 where medicamento_id = 411;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (47, 106, 106, 2, 134.10, 654.78);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 106;
# update estoque_total set total = total - 2 where medicamento_id = 106;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (411, 'lote 793494', '2023-08-31', '2026-03-31', 29.4, 14, 14);
# update estoque_total set total = total + 14 where medicamento_id = 411;
#
# insert into venda (profissional_id, time_stamp, total) values (24, '2023-09-02 00:15:41', 573.94);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (48, 96, 96, 1, 12.70, 241.34);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 96;
# update estoque_total set total = total - 1 where medicamento_id = 96;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (48, 83, 83, 2, 0.00, 187.24);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 83;
# update estoque_total set total = total - 2 where medicamento_id = 83;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (48, 340, 340, 7, 2.90, 145.36);
# update estoque set quant_venda = quant_venda + 7, quant_atual = quant_atual - 7 where id = 340;
# update estoque_total set total = total - 7 where medicamento_id = 340;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (83, 'lote 979304', '2023-09-02', '2026-03-31', 39.6, 14, 14);
# update estoque_total set total = total + 14 where medicamento_id = 83;
#
# insert into venda (profissional_id, time_stamp, total) values (23, '2023-09-02 00:58:30', 95.50);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (49, 475, 475, 5, 5.00, 95.50);
# update estoque set quant_venda = quant_venda + 5, quant_atual = quant_atual - 5 where id = 475;
# update estoque_total set total = total - 5 where medicamento_id = 475;
#
# insert into venda (profissional_id, time_stamp, total) values (25, '2023-09-03 10:14:43', 648.67);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (50, 397, 397, 2, 2.10, 34.14);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 397;
# update estoque_total set total = total - 2 where medicamento_id = 397;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (50, 176, 176, 1, 30.60, 310.24);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 176;
# update estoque_total set total = total - 1 where medicamento_id = 176;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (50, 74, 74, 3, 3.00, 304.29);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 74;
# update estoque_total set total = total - 3 where medicamento_id = 74;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (176, 'lote 320871', '2023-09-03', '2025-03-31', 148.9, 6, 6);
# update estoque_total set total = total + 6 where medicamento_id = 176;
#
# insert into venda (profissional_id, time_stamp, total) values (24, '2023-09-03 12:34:55', 647.10);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (51, 288, 288, 3, 0.00, 49.02);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 288;
# update estoque_total set total = total - 3 where medicamento_id = 288;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (51, 198, 198, 6, 0.00, 245.46);
# update estoque set quant_venda = quant_venda + 6, quant_atual = quant_atual - 6 where id = 198;
# update estoque_total set total = total - 6 where medicamento_id = 198;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (51, 353, 353, 9, 22.50, 352.62);
# update estoque set quant_venda = quant_venda + 9, quant_atual = quant_atual - 9 where id = 353;
# update estoque_total set total = total - 9 where medicamento_id = 353;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (1, 23, '2023-09-03 14:29:14', 103.70);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (52, 389, 389, 5, 58.30, 103.70);
# update estoque set quant_venda = quant_venda + 5, quant_atual = quant_atual - 5 where id = 389;
# update estoque_total set total = total - 5 where medicamento_id = 389;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (20, 23, '2023-09-04 22:55:27', 461.80);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (53, 478, 478, 1, 10.90, 46.62);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 478;
# update estoque_total set total = total - 1 where medicamento_id = 478;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (53, 410, 410, 3, 64.00, 256.34);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 410;
# update estoque_total set total = total - 3 where medicamento_id = 410;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (53, 413, 413, 2, 21.60, 158.84);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 413;
# update estoque_total set total = total - 2 where medicamento_id = 413;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (10, 21, '2023-09-04 23:50:37', 271.14);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (54, 475, 475, 5, 39.10, 61.40);
# update estoque set quant_venda = quant_venda + 5, quant_atual = quant_atual - 5 where id = 475;
# update estoque_total set total = total - 5 where medicamento_id = 475;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (54, 455, 455, 2, 25.00, 75.34);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 455;
# update estoque_total set total = total - 2 where medicamento_id = 455;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (54, 464, 464, 6, 60.30, 134.40);
# update estoque set quant_venda = quant_venda + 6, quant_atual = quant_atual - 6 where id = 464;
# update estoque_total set total = total - 6 where medicamento_id = 464;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (455, 'lote 102237', '2023-09-04', '2024-03-31', 25.6, 14, 14);
# update estoque_total set total = total + 14 where medicamento_id = 455;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (20, 22, '2023-09-06 08:20:34', 147.67);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (55, 171, 171, 3, 66.20, 147.67);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 171;
# update estoque_total set total = total - 3 where medicamento_id = 171;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (171, 'lote 180156', '2023-09-06', '2026-03-31', 33.1, 18, 18);
# update estoque_total set total = total + 18 where medicamento_id = 171;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (2, 21, '2023-09-06 09:50:27', 32.46);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (56, 294, 294, 3, 17.40, 32.46);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 294;
# update estoque_total set total = total - 3 where medicamento_id = 294;
#
# insert into venda (profissional_id, time_stamp, total) values (23, '2023-09-06 11:42:36', 949.78);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (57, 184, 184, 4, 7.60, 77.00);
# update estoque set quant_venda = quant_venda + 4, quant_atual = quant_atual - 4 where id = 184;
# update estoque_total set total = total - 4 where medicamento_id = 184;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (57, 36, 36, 2, 26.10, 626.78);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 36;
# update estoque_total set total = total - 2 where medicamento_id = 36;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (57, 255, 255, 5, 7.60, 246.00);
# update estoque set quant_venda = quant_venda + 5, quant_atual = quant_atual - 5 where id = 255;
# update estoque_total set total = total - 5 where medicamento_id = 255;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (36, 'lote 415768', '2023-09-06', '2024-03-31', 177.9, 6, 6);
# update estoque_total set total = total + 6 where medicamento_id = 36;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (7, 23, '2023-09-07 18:19:13', 234.57);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (58, 311, 311, 3, 5.40, 40.23);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 311;
# update estoque_total set total = total - 3 where medicamento_id = 311;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (58, 301, 301, 1, 95.60, 194.34);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 301;
# update estoque_total set total = total - 1 where medicamento_id = 301;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (9, 21, '2023-09-07 21:58:08', 523.02);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (59, 343, 343, 3, 0.00, 94.32);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 343;
# update estoque_total set total = total - 3 where medicamento_id = 343;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (59, 123, 123, 5, 7.70, 250.90);
# update estoque set quant_venda = quant_venda + 5, quant_atual = quant_atual - 5 where id = 123;
# update estoque_total set total = total - 5 where medicamento_id = 123;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (59, 387, 387, 3, 17.50, 177.80);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 387;
# update estoque_total set total = total - 3 where medicamento_id = 387;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (343, 'lote 846309', '2023-09-07', '2024-03-31', 11.0, 47, 47);
# update estoque_total set total = total + 47 where medicamento_id = 343;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (387, 'lote 370904', '2023-09-07', '2024-03-31', 28.6, 2, 2);
# update estoque_total set total = total + 2 where medicamento_id = 387;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (14, 24, '2023-09-08 01:30:40', 209.36);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (60, 410, 410, 2, 4.20, 209.36);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 410;
# update estoque_total set total = total - 2 where medicamento_id = 410;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (410, 'lote 159773', '2023-09-08', '2026-09-30', 47.9, 5, 5);
# update estoque_total set total = total + 5 where medicamento_id = 410;
#
# ...
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (159, 475, 475, 5, 10.00, 90.50);
# update estoque set quant_venda = quant_venda + 5, quant_atual = quant_atual - 5 where id = 475;
# update estoque_total set total = total - 5 where medicamento_id = 475;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (159, 165, 165, 2, 23.60, 55.20);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 165;
# update estoque_total set total = total - 2 where medicamento_id = 165;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (14, 24, '2023-11-15 09:26:33', 417.24);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (160, 158, 158, 1, 13.00, 105.60);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 158;
# update estoque_total set total = total - 1 where medicamento_id = 158;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (160, 106, 106, 1, 82.80, 311.64);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 106;
# update estoque_total set total = total - 1 where medicamento_id = 106;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (11, 22, '2023-11-15 09:40:53', 179.20);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (161, 458, 458, 5, 1.80, 179.20);
# update estoque set quant_venda = quant_venda + 5, quant_atual = quant_atual - 5 where id = 458;
# update estoque_total set total = total - 5 where medicamento_id = 458;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (458, 'lote 126610', '2023-11-15', '2024-11-30', 16.8, 27, 27);
# update estoque_total set total = total + 27 where medicamento_id = 458;
#
# insert into venda (profissional_id, time_stamp, total) values (24, '2023-11-18 01:56:16', 371.43);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (162, 496, 566, 3, 0.40, 21.71);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 566;
# update estoque_total set total = total - 3 where medicamento_id = 496;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (162, 264, 264, 2, 3.90, 94.42);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 264;
# update estoque_total set total = total - 2 where medicamento_id = 264;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (162, 321, 559, 10, 25.20, 255.30);
# update estoque set quant_venda = quant_venda + 10, quant_atual = quant_atual - 10 where id = 559;
# update estoque_total set total = total - 10 where medicamento_id = 321;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (264, 'lote 535240', '2023-11-18', '2025-05-31', 23.5, 2, 2);
# update estoque_total set total = total + 2 where medicamento_id = 264;
#
# insert into venda (profissional_id, time_stamp, total) values (23, '2023-11-18 05:48:37', 376.18);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (163, 59, 59, 4, 3.70, 376.18);
# update estoque set quant_venda = quant_venda + 4, quant_atual = quant_atual - 4 where id = 59;
# update estoque_total set total = total - 4 where medicamento_id = 59;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (5, 22, '2023-11-18 09:12:11', 594.15);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (164, 209, 209, 3, 11.00, 127.06);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 209;
# update estoque_total set total = total - 3 where medicamento_id = 209;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (164, 195, 195, 1, 7.70, 250.75);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 195;
# update estoque_total set total = total - 1 where medicamento_id = 195;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (164, 354, 354, 4, 75.90, 216.34);
# update estoque set quant_venda = quant_venda + 4, quant_atual = quant_atual - 4 where id = 354;
# update estoque_total set total = total - 4 where medicamento_id = 354;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (1, 23, '2023-11-18 11:41:20', 34.16);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (165, 218, 218, 2, 12.60, 34.16);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 218;
# update estoque_total set total = total - 2 where medicamento_id = 218;
#
# insert into venda (profissional_id, time_stamp, total) values (24, '2023-11-19 14:29:07', 611.10);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (166, 310, 310, 5, 6.10, 611.10);
# update estoque set quant_venda = quant_venda + 5, quant_atual = quant_atual - 5 where id = 310;
# update estoque_total set total = total - 5 where medicamento_id = 310;
#
# insert into venda (profissional_id, time_stamp, total) values (24, '2023-11-19 15:21:03', 280.84);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (167, 92, 92, 6, 8.60, 280.84);
# update estoque set quant_venda = quant_venda + 6, quant_atual = quant_atual - 6 where id = 92;
# update estoque_total set total = total - 6 where medicamento_id = 92;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (7, 22, '2023-11-22 05:56:03', 910.38);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (168, 86, 86, 2, 14.40, 274.20);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 86;
# update estoque_total set total = total - 2 where medicamento_id = 86;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (168, 108, 108, 3, 56.90, 575.74);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 108;
# update estoque_total set total = total - 3 where medicamento_id = 108;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (168, 303, 303, 2, 1.20, 60.44);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 303;
# update estoque_total set total = total - 2 where medicamento_id = 303;
#
# insert into venda (profissional_id, time_stamp, total) values (23, '2023-11-24 23:25:18', 528.08);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (169, 395, 395, 3, 8.60, 115.21);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 395;
# update estoque_total set total = total - 3 where medicamento_id = 395;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (169, 395, 395, 8, 26.40, 303.76);
# update estoque set quant_venda = quant_venda + 8, quant_atual = quant_atual - 8 where id = 395;
# update estoque_total set total = total - 8 where medicamento_id = 395;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (169, 53, 53, 1, 9.40, 109.11);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 53;
# update estoque_total set total = total - 1 where medicamento_id = 53;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (53, 'lote 469807', '2023-11-24', '2025-05-31', 53.4, 15, 15);
# update estoque_total set total = total + 15 where medicamento_id = 53;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (1, 25, '2023-11-25 02:31:44', 427.49);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (170, 308, 308, 3, 1.50, 158.01);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 308;
# update estoque_total set total = total - 3 where medicamento_id = 308;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (170, 187, 187, 8, 26.60, 269.48);
# update estoque set quant_venda = quant_venda + 8, quant_atual = quant_atual - 8 where id = 187;
# update estoque_total set total = total - 8 where medicamento_id = 187;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (6, 22, '2023-11-25 04:36:25', 106.34);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (171, 393, 393, 1, 9.00, 15.52);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 393;
# update estoque_total set total = total - 1 where medicamento_id = 393;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (171, 384, 384, 3, 40.70, 90.82);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 384;
# update estoque_total set total = total - 3 where medicamento_id = 384;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (393, 'lote 631284', '2023-11-25', '2024-05-31', 8.6, 23, 23);
# update estoque_total set total = total + 23 where medicamento_id = 393;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (16, 24, '2023-11-25 07:30:10', 440.54);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (172, 47, 47, 2, 54.40, 440.54);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 47;
# update estoque_total set total = total - 2 where medicamento_id = 47;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (4, 22, '2023-11-26 17:27:19', 241.78);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (173, 149, 149, 3, 0.00, 82.77);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 149;
# update estoque_total set total = total - 3 where medicamento_id = 149;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (173, 492, 492, 1, 13.20, 31.13);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 492;
# update estoque_total set total = total - 1 where medicamento_id = 492;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (173, 255, 255, 4, 75.00, 127.88);
# update estoque set quant_venda = quant_venda + 4, quant_atual = quant_atual - 4 where id = 255;
# update estoque_total set total = total - 4 where medicamento_id = 255;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (3, 25, '2023-11-26 17:36:37', 485.90);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (174, 196, 196, 3, 204.40, 363.38);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 196;
# update estoque_total set total = total - 3 where medicamento_id = 196;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (174, 310, 310, 1, 39.50, 83.94);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 310;
# update estoque_total set total = total - 1 where medicamento_id = 310;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (174, 386, 386, 3, 16.50, 38.58);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 386;
# update estoque_total set total = total - 3 where medicamento_id = 386;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (2, 23, '2023-11-27 21:12:48', 154.17);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (175, 80, 80, 1, 82.90, 154.17);
# update estoque set quant_venda = quant_venda + 1, quant_atual = quant_atual - 1 where id = 80;
# update estoque_total set total = total - 1 where medicamento_id = 80;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (8, 24, '2023-11-28 00:20:55', 192.58);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (176, 353, 353, 6, 57.50, 192.58);
# update estoque set quant_venda = quant_venda + 6, quant_atual = quant_atual - 6 where id = 353;
# update estoque_total set total = total - 6 where medicamento_id = 353;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (353, 'lote 489520', '2023-11-28', '2026-05-31', 16.7, 18, 18);
# update estoque_total set total = total + 18 where medicamento_id = 353;
#
# insert into venda (cliente_id, profissional_id, time_stamp, total) values (15, 25, '2023-11-29 07:45:43', 89.30);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (177, 493, 493, 5, 1.80, 36.00);
# update estoque set quant_venda = quant_venda + 5, quant_atual = quant_atual - 5 where id = 493;
# update estoque_total set total = total - 5 where medicamento_id = 493;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (177, 286, 286, 2, 15.80, 53.30);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 286;
# update estoque_total set total = total - 2 where medicamento_id = 286;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (286, 'lote 618970', '2023-11-29', '2026-11-30', 14.4, 43, 43);
# update estoque_total set total = total + 43 where medicamento_id = 286;
#
# insert into venda (profissional_id, time_stamp, total) values (24, '2023-11-29 11:13:58', 364.51);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (178, 212, 573, 2, 4.90, 119.64);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 573;
# update estoque_total set total = total - 2 where medicamento_id = 212;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (178, 369, 369, 3, 24.20, 244.87);
# update estoque set quant_venda = quant_venda + 3, quant_atual = quant_atual - 3 where id = 369;
# update estoque_total set total = total - 3 where medicamento_id = 369;
# insert into estoque (medicamento_id, lote, data, validade, preco, quant_inicial, quant_atual) values (212, 'lote 779369', '2023-11-29', '2024-12-31', 25.8, 6, 6);
# update estoque_total set total = total + 6 where medicamento_id = 212;
#
# insert into venda (profissional_id, time_stamp, total) values (22, '2023-11-30 23:28:03', 597.88);
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (179, 190, 190, 2, 4.40, 443.46);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 190;
# update estoque_total set total = total - 2 where medicamento_id = 190;
# insert into itens_venda (venda_id, medicamento_id, estoque_id, quantidade, desconto, total) values (179, 65, 65, 2, 0.00, 154.42);
# update estoque set quant_venda = quant_venda + 2, quant_atual = quant_atual - 2 where id = 65;
# update estoque_total set total = total - 2 where medicamento_id = 65;
